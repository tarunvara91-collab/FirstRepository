# %% [markdown]
# <a href="https://colab.research.google.com/github/tarunvara91-collab/FirstRepository/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
- simple syntax
- powerful libraries: numpy, pandas, matplotlib, scikitlearn
- large community support

# %%
#my first print statement
print("Welcome to Python for Data Analysis class")
# Out:
# Welcome to Python for Data Analysis class

# %%
name = "Tarun"
age = 29
height = 167.5
is_student = True

# %%
name
# Out:
# 'Tarun'

# %%
age
# Out:
# 29

# %%
height
# Out:
# 167.5

# %%
is_student
# Out:
# True

# %%
name = "tarun"

# %%
name
# Out:
# 'tarun'

# %%
is_student = "True"

# %%
is_student
# Out:
# 'True'

# %%
l1 = ["Tarun", 29, True, 167.5]
l1
# Out:
# ['Tarun', 29, True, 167.5]

# %%
print("Age is", l1[1])
# Out:
# Age is 29
